# %%
##import all basic library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
##read the csv file/import the file
df=pd.read_csv('movies.csv')

# %%
###show the dataframe
df
# Out:
#       Unnamed: 0      id                        title  \
# 0              0     278     The Shawshank Redemption
# 1              1   19404  Dilwale Dulhania Le Jayenge
# 2              2     238                The Godfather
# 3              3     424             Schindler's List
# 4              4     240       The Godfather: Part II
# ...          ...     ...                          ...
# 8555        8555    8457              Drillbit Taylor
# 8556        8556  445583         It's All About Karma
# 8557        8557  411873             The Little Hours
# 8558        8558  227783                  The Nut Job
# 8559        8559  446170                   Black Tide
#
#                                                overview release_date  \
# 0     Framed in the 1940s for the double murder of h...   23-09-1994
# 1     Raj is a rich, carefree, happy-go-lucky second...   20-10-1995
# 2     Spanning the years 1945 to 1955, a chronicle o...   14-03-1972
# ...

# %%
df=df.drop(['Unnamed: 0','id'],axis=1)  ##removing unwanted columns

# %%
df
# Out:
#                             title  \
# 0        The Shawshank Redemption
# 1     Dilwale Dulhania Le Jayenge
# 2                   The Godfather
# 3                Schindler's List
# 4          The Godfather: Part II
# ...                           ...
# 8555              Drillbit Taylor
# 8556         It's All About Karma
# 8557             The Little Hours
# 8558                  The Nut Job
# 8559                   Black Tide
#
#                                                overview release_date  \
# 0     Framed in the 1940s for the double murder of h...   23-09-1994
# 1     Raj is a rich, carefree, happy-go-lucky second...   20-10-1995
# 2     Spanning the years 1945 to 1955, a chronicle o...   14-03-1972
# 3     The true story of how businessman Oskar Schind...   30-11-1993
# 4     In the continuing saga of the Corleone crime f...   20-12-1974
# ...                                                 ...          ...
# ...

# %%
df.head()## top 5 rows
# Out:
#                          title  \
# 0     The Shawshank Redemption
# 1  Dilwale Dulhania Le Jayenge
# 2                The Godfather
# 3             Schindler's List
# 4       The Godfather: Part II
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   23-09-1994      62.636
# 1  Raj is a rich, carefree, happy-go-lucky second...   20-10-1995      19.097
# 2  Spanning the years 1945 to 1955, a chronicle o...   14-03-1972      57.656
# 3  The true story of how businessman Oskar Schind...   30-11-1993      41.077
# 4  In the continuing saga of the Corleone crime f...   20-12-1974      46.655
#
#    vote_average  vote_count
# 0           8.7       21456
# 1           8.7        3652
# 2           8.7       15990
# 3           8.6       12778
# 4           8.6        9640

# %%
df.tail()##bottom 5 rows
# Out:
#                      title                                           overview  \
# 8555       Drillbit Taylor  Three kids hire a low-budget bodyguard to prot...
# 8556  It's All About Karma  Giacomo befriends a con man, believing that he...
# 8557      The Little Hours  Garfagnana, Italy, 1347. The handsome servant ...
# 8558           The Nut Job  Surly, a curmudgeon, independent squirrel is b...
# 8559            Black Tide  When a teenager suddenly disappears without a ...
#
#      release_date  popularity  vote_average  vote_count
# 8555   04-02-2008       9.382           5.7         827
# 8556   09-03-2017       5.406           5.7         250
# 8557   30-06-2017      23.265           5.7         419
# 8558   17-01-2014      17.392           5.7         794
# 8559   18-07-2018       6.485           5.7         225

# %%
df.columns
# Out:
# Index(['title', 'overview', 'release_date', 'popularity', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df.shape
# Out:
# (8560, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8560 entries, 0 to 8559
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         8560 non-null   object
#  1   overview      8556 non-null   object
#  2   release_date  8560 non-null   object
#  3   popularity    8560 non-null   float64
#  4   vote_average  8560 non-null   float64
#  5   vote_count    8560 non-null   int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 401.4+ KB

# %%
df.describe()
# Out:
#          popularity  vote_average    vote_count
# count   8560.000000   8560.000000   8560.000000
# mean      34.483893      6.803832   1663.763201
# std      259.280939      0.632387   2777.837511
# min        0.600000      5.700000    198.000000
# 25%        8.350000      6.300000    327.000000
# 50%       11.703000      6.700000    625.000000
# 75%       21.335250      7.300000   1619.250000
# max    11288.261000      8.700000  31575.000000

# %%
df.isna().sum()##check the null value/empty value
# Out:
# title           0
# overview        4
# release_date    0
# popularity      0
# vote_average    0
# vote_count      0
# dtype: int64

# %%
df=df.drop(['overview'],axis=1)

# %%
df
# Out:
#                             title release_date  popularity  vote_average  \
# 0        The Shawshank Redemption   23-09-1994      62.636           8.7
# 1     Dilwale Dulhania Le Jayenge   20-10-1995      19.097           8.7
# 2                   The Godfather   14-03-1972      57.656           8.7
# 3                Schindler's List   30-11-1993      41.077           8.6
# 4          The Godfather: Part II   20-12-1974      46.655           8.6
# ...                           ...          ...         ...           ...
# 8555              Drillbit Taylor   04-02-2008       9.382           5.7
# 8556         It's All About Karma   09-03-2017       5.406           5.7
# 8557             The Little Hours   30-06-2017      23.265           5.7
# 8558                  The Nut Job   17-01-2014      17.392           5.7
# 8559                   Black Tide   18-07-2018       6.485           5.7
#
#       vote_count
# 0          21456
# 1           3652
# 2          15990
# 3          12778
# ...

# %%
df.duplicated().sum() ##check the duplicate value
# Out:
# 0

# %%
df
# Out:
#                             title release_date  popularity  vote_average  \
# 0        The Shawshank Redemption   23-09-1994      62.636           8.7
# 1     Dilwale Dulhania Le Jayenge   20-10-1995      19.097           8.7
# 2                   The Godfather   14-03-1972      57.656           8.7
# 3                Schindler's List   30-11-1993      41.077           8.6
# 4          The Godfather: Part II   20-12-1974      46.655           8.6
# ...                           ...          ...         ...           ...
# 8555              Drillbit Taylor   04-02-2008       9.382           5.7
# 8556         It's All About Karma   09-03-2017       5.406           5.7
# 8557             The Little Hours   30-06-2017      23.265           5.7
# 8558                  The Nut Job   17-01-2014      17.392           5.7
# 8559                   Black Tide   18-07-2018       6.485           5.7
#
#       vote_count
# 0          21456
# 1           3652
# 2          15990
# 3          12778
# ...

# %%
x=df['release_date'].str.split('-',n=2,expand=True) ##spliting a column by notation

# %%
df['day']=x[0]
df['month']=x[1]
df['year']=x[2]

# %%
df
# Out:
#                             title release_date  popularity  vote_average  \
# 0        The Shawshank Redemption   23-09-1994      62.636           8.7
# 1     Dilwale Dulhania Le Jayenge   20-10-1995      19.097           8.7
# 2                   The Godfather   14-03-1972      57.656           8.7
# 3                Schindler's List   30-11-1993      41.077           8.6
# 4          The Godfather: Part II   20-12-1974      46.655           8.6
# ...                           ...          ...         ...           ...
# 8555              Drillbit Taylor   04-02-2008       9.382           5.7
# 8556         It's All About Karma   09-03-2017       5.406           5.7
# 8557             The Little Hours   30-06-2017      23.265           5.7
# 8558                  The Nut Job   17-01-2014      17.392           5.7
# 8559                   Black Tide   18-07-2018       6.485           5.7
#
#       vote_count day month  year
# 0          21456  23    09  1994
# ...

# %%
df.nunique()
# Out:
# title           8307
# release_date    5601
# popularity      7134
# vote_average      31
# vote_count      3075
# day               31
# month             12
# year             109
# dtype: int64

# %%
df['vote_average'].unique()
# Out:
# array([8.7, 8.6, 8.5, 8.4, 8.3, 8.2, 8.1, 8. , 7.9, 7.8, 7.7, 7.6, 7.5,
#        7.4, 7.3, 7.2, 7.1, 7. , 6.9, 6.8, 6.7, 6.6, 6.5, 6.4, 6.3, 6.2,
#        6.1, 6. , 5.9, 5.8, 5.7])

# %%
df['vote_average'].value_counts() ##count of individuals
# Out:
# 6.7    478
# 6.4    475
# 6.5    469
# 6.6    465
# 6.8    445
# 6.1    445
# 6.3    434
# 6.2    427
# 6.9    411
# 7.2    408
# 7.0    407
# 7.1    399
# 6.0    390
# 7.4    364
# 7.3    357
# 5.9    354
# 7.5    344
# 5.8    294
# 7.6    231
# 7.7    198
# 7.8    177
# 7.9    154
# 8.0    122
# 8.1     82
# 8.2     66
# 5.7     54
# 8.3     47
# 8.4     35
# 8.5     21
# 8.6      4
# 8.7      3
# Name: vote_average, dtype: int64

# %%
##show data in plot
plt.figure(figsize=(15,5))
sns.countplot('vote_average',data=df,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
import plotly.express as px  ##for more interactive plot

# %%
f1=px.histogram(df,x='vote_average')
f1.show()
# Out:
# <div>                            <div id="da57de11-d101-414d-94e2-7bc6ef821d52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da57de11-d101-414d-94e2-7bc6ef821d52")) {                    Plotly.newPlot(                        "da57de11-d101-414d-94e2-7bc6ef821d52",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"vote_average=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[8.7,8.7,8.7,8.6,8.6,8.6,8.6,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.5,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.4,
# ...

# %%
f2=px.histogram(df,x='vote_average',color='vote_average')
f2.show()
# Out:
# <div>                            <div id="3d86049c-785b-4508-a25c-7f3e5c1d8d1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d86049c-785b-4508-a25c-7f3e5c1d8d1f")) {                    Plotly.newPlot(                        "3d86049c-785b-4508-a25c-7f3e5c1d8d1f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"vote_average=%{x}<br>count=%{y}<extra></extra>","legendgroup":"8.7","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"8.7","offsetgroup":"8.7","orientation":"v","showlegend":true,"x":[8.7,8.7,8.7],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"vote_average=%{x}<br>count=%{y}<extra></extra>","legendgroup":"8.6","marker":{"color":"#EF553B","patte
# ...

# %%
##top popular movies
df_popular=df.copy()##make a copy of dataframe

# %%
df_popular
# Out:
#                             title release_date  popularity  vote_average  \
# 0        The Shawshank Redemption   23-09-1994      62.636           8.7
# 1     Dilwale Dulhania Le Jayenge   20-10-1995      19.097           8.7
# 2                   The Godfather   14-03-1972      57.656           8.7
# 3                Schindler's List   30-11-1993      41.077           8.6
# 4          The Godfather: Part II   20-12-1974      46.655           8.6
# ...                           ...          ...         ...           ...
# 8555              Drillbit Taylor   04-02-2008       9.382           5.7
# 8556         It's All About Karma   09-03-2017       5.406           5.7
# 8557             The Little Hours   30-06-2017      23.265           5.7
# 8558                  The Nut Job   17-01-2014      17.392           5.7
# 8559                   Black Tide   18-07-2018       6.485           5.7
#
#       vote_count day month  year
# 0          21456  23    09  1994
# ...

# %%
df_popular=df_popular.sort_values(by='popularity',ascending=False) ##sorting the dataframe by popularity in descending order

# %%
df_popular
# Out:
#                      title release_date  popularity  vote_average  vote_count  \
# 4238         The Lost City   24-03-2022   11288.261           6.7         768
# 6238               Morbius   30-03-2022   11236.546           6.3        1125
# 1400          The Northman   07-04-2022    7895.411           7.5        1095
# 703   Sonic the Hedgehog 2   30-03-2022    7088.307           7.8        1622
# 638             The Batman   01-03-2022    6372.913           7.8        4767
# ...                    ...          ...         ...           ...         ...
# 5282            Stalingrad   09-10-2013       0.600           6.5         275
# 3170             Manhunter   14-08-1986       0.600           7.0         986
# 3642                Tracks   19-12-2013       0.600           6.9         415
# 7791                G.B.F.   19-04-2013       0.600           6.0         369
# 41      Hotarubi no Mori e   17-09-2011       0.600           8.4         779
#
#      day month  year
# ...

# %%
plt.figure(figsize=(15,5))
plt.title('Average_vote VS Popularity')
sns.barplot(data=df_popular,x='vote_average',y='popularity')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Count_of_vote VS Popularity')
sns.barplot(data=df_popular.head(10),x='vote_count',y='popularity')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Year wise Vote Count')
sns.barplot(data=df_popular.head(100),x='vote_count',y='year')
plt.xticks(rotation=90)
plt.show()

# %%
##top 30 movies by popularity
plt.figure(figsize=(15,5))
plt.title('Top 30 Popular Movies')
sns.barplot(data=df_popular.head(30),x='title',y='popularity')
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#                             title release_date  popularity  vote_average  \
# 0        The Shawshank Redemption   23-09-1994      62.636           8.7
# 1     Dilwale Dulhania Le Jayenge   20-10-1995      19.097           8.7
# 2                   The Godfather   14-03-1972      57.656           8.7
# 3                Schindler's List   30-11-1993      41.077           8.6
# 4          The Godfather: Part II   20-12-1974      46.655           8.6
# ...                           ...          ...         ...           ...
# 8555              Drillbit Taylor   04-02-2008       9.382           5.7
# 8556         It's All About Karma   09-03-2017       5.406           5.7
# 8557             The Little Hours   30-06-2017      23.265           5.7
# 8558                  The Nut Job   17-01-2014      17.392           5.7
# 8559                   Black Tide   18-07-2018       6.485           5.7
#
#       vote_count day month  year
# 0          21456  23    09  1994
# ...

# %%
df_vote_average=df.copy()

# %%
df_vote_average=df_vote_average.sort_values(by='vote_average',ascending=False)

# %%
df_vote_average
# Out:
#                             title release_date  popularity  vote_average  \
# 0        The Shawshank Redemption   23-09-1994      62.636           8.7
# 2                   The Godfather   14-03-1972      57.656           8.7
# 1     Dilwale Dulhania Le Jayenge   20-10-1995      19.097           8.7
# 3                Schindler's List   30-11-1993      41.077           8.6
# 4          The Godfather: Part II   20-12-1974      46.655           8.6
# ...                           ...          ...         ...           ...
# 8527             Are We Done Yet?   04-04-2007      10.547           5.7
# 8528        Paranormal Activity 2   20-10-2010      20.364           5.7
# 8529                   Nine Lives   03-08-2016      10.252           5.7
# 8530                  Young Adult   11-11-2011      15.695           5.7
# 8559                   Black Tide   18-07-2018       6.485           5.7
#
#       vote_count day month  year
# 0          21456  23    09  1994
# ...

# %%
##top movies by average_vote
plt.figure(figsize=(15,5))
plt.title('Average vote count')
sns.countplot('vote_average',data=df_vote_average,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ###### Finding Outliers

# %%
##finding outliers in popularity column
plt.figure(figsize=(15,6))
plt.title('Outliers of Popularity')
sns.boxplot(df['popularity'])
plt.xticks(rotation = 90)
plt.show()

# %%
popularity_d=df['popularity']
Q3=popularity_d.quantile(.75)
Q1=popularity_d.quantile(.25)
IQR=Q3-Q1
lower_limit = Q1 -(1.5*IQR)
upper_limit = Q3 +(1.5*IQR)
popularity_outliers=popularity_d[(popularity_d<lower_limit)|(popularity_d>upper_limit)]

# %%
popularity_outliers
# Out:
# 1       19.097
# 5       21.407
# 6        8.612
# 9        9.550
# 10      12.001
#          ...
# 8555     9.382
# 8556     5.406
# 8557    23.265
# 8558    17.392
# 8559     6.485
# Name: popularity, Length: 7532, dtype: float64

# %%
popularity_filtered=popularity_d[(popularity_d>lower_limit)&(popularity_d<upper_limit)]
# Out:
# Series([], Name: popularity, dtype: float64)

# %%
popularity_filtered
# Out:
# Series([], Name: popularity, dtype: float64)

# %%
##finding outliers in vote_average column
plt.figure(figsize=(15,5))
plt.title('Outliers of Average Vote')
sns.boxplot(df['vote_average'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.boxplot(df['vote_count'])
plt.show()

# %%
vote_count_d=df['vote_count']
Q1=vote_count_d.quantile(.75)
Q3=vote_count_d.quantile(.25)
IQR=Q3-Q1
lower_limit=Q1-(IQR*1.5)
upper_limit=Q3+(IQR*1.5)
vote_count_outliers=vote_count_d[(vote_count_d<lower_limit)|(vote_count_d>upper_limit)]

# %%
vote_count_outliers
# Out:
# 0       21456
# 1        3652
# 2       15990
# 3       12778
# 4        9640
#         ...
# 8555      827
# 8556      250
# 8557      419
# 8558      794
# 8559      225
# Name: vote_count, Length: 8560, dtype: int64

# %%
vote_count_filtered=vote_count_d[(vote_count_d>lower_limit)&(vote_count_d<upper_limit)]

# %%
vote_count_filtered
# Out:
# Series([], Name: vote_count, dtype: int64)

# %%
df.corr()
# Out:
#               popularity  vote_average  vote_count
# popularity      1.000000      0.036491    0.071668
# vote_average    0.036491      1.000000    0.253971
# vote_count      0.071668      0.253971    1.000000

# %%
plt.figure(figsize=(15,6))
plt.title('Corelation among Data')
sns.heatmap(df.corr(), annot = True)
plt.show()
